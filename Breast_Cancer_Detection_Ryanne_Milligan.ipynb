# %% [markdown]
# <a href="https://colab.research.google.com/github/ryannemilligan/Breast-Cancer-Detection---Ryanne-Milligan./blob/main/Breast_Cancer_Detection_Ryanne_Milligan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Breast Cancer Detection

# %% [markdown]
# # The Scenario
# “About 1 in 8 U.S. women (about 13%) will develop invasive breast cancer over the course of her lifetime. <br>
# In 2021, an estimated 281,550 new cases of invasive breast cancer are expected to be diagnosed in women in the U.S., along with 49,290 new cases of non-invasive (in situ) breast cancer.”<br>
#
# A timely response is crucial so that real invasive cases are treated promptly, while we do not put those in non-invasive cases under unnecessary tests or procedures.<br>
# However, there is a crunch on professionals to check on the reports.<br>
# Is there a way to overcome this problem?<br>
#
# Source: U.S. Breast Cancer Statistics. BreastCancer Org. https://www.breastcancer.org/symptoms/understand_bc/statistics

# %% [markdown]
# # Tips for working on this project
# You will be using these two concepts to be able to successfully complete this project:
# 1. Supervised Learning models
# 2. AI Project Cycle <br>
#
# If needed, please revise your notes on these topics.

# %% [markdown]
# # Section 1: Understand the Problem
#
# One of the key points of solving an AI problem is to understand the problem statement correctly. <br>
# You need to understand what is the correct problems that you are solving.<br>
# You want to solve the root problem and not the symptoms.<br>
# To do that, you can use tools like 5 Whys, decomposition, and Fish-bone diagram.<br>
# You can then write your problem statement.<br>
# It may include helpful information, like who is affected, what is the problem, where is it happening, and when does it happen.<br>
# need more details to each.<br>
#
# Based on the scenario above, write your problem statement in the cell below!<br>

# %%
# The biggest problem is that we don't have enough medical experts on this
# specific topic to quickly and effectively check all breast cancer reports
# which delays diagnosis.

# For this project I will be aiming to create a smart computer program that
# doctors can use for quick and accurate case classification resulting in
# faster diagnosis for patients.

# %% [markdown]
# # Section 2: Data Acquisition
#
# Data is the main ingredient for AI model. <br>
# Where can you find your data? <br>
# Write your answer in the cell below. <br>
#
# In this scenario, you are given a CSV file with the info.<br>
# In the cell below, write down which column will serve as a target for your AI model?

# %%
# The target column for my AI model will be "diagnosis". This column tells us
# if this cancer is "M" for malignant, or "B" for benign.

# %% [markdown]
# # Import libraries and insert the file

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier # imported KNN classifier
from sklearn.svm import SVC # imported SVC classifier
from sklearn.tree import DecisionTreeClassifier # imported SVC classifier

# import data source
df = pd.read_csv("[Dataset]_BreastCancer.csv")
df = df.dropna()
print(df.head())

X = df.drop(columns=['diagnosis'])
y = df['diagnosis']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# scale features for better KNN and SVC accuracies
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Model 1 : KNN
# Your answer here!
knn=KNeighborsClassifier()
knn.fit(X_train, y_train)
print("KNN Accuracy:", accuracy_score(y_test, knn.predict(X_test)))


# Model 2 : SVC
# Your answer here!
svc = SVC()
svc.fit(X_train, y_train)
print('SVC Accuracy:', accuracy_score(y_test, svc.predict(X_test)))


# Model 3 : Decision Tree
# Your answer here!
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
print('Decision Tree Accuracy:', accuracy_score(y_test, dt.predict(X_test)))


df
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
# 5          0.12780           0.17000          0.1578              0.08089
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
# 5  ...         15.47          23.75           103.40       741.6
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
# 5            0.1791             0.5249           0.5355                0.1741
#
#    symmetry_worst  fractal_dimension_worst
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
# 5          0.3985                  0.12440
#
# [5 rows x 32 columns]
# KNN Accuracy: 0.9705882352941176
# SVC Accuracy: 0.9779411764705882
# Decision Tree Accuracy: 0.9191176470588235
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# 5      843786         M        12.45         15.70           82.57      477.1
# ..        ...       ...          ...           ...             ...        ...
# 563    926125         M        20.92         25.09          143.00     1347.0
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 1            0.08474           0.07864          0.0869              0.07017
# 2            0.10960           0.15990          0.1974              0.12790
# 3            0.14250           0.28390          0.2414              0.10520
# 4            0.10030           0.13280          0.1980              0.10430
# 5            0.12780           0.17000          0.1578              0.08089
# ..               ...               ...             ...                  ...
# 563          0.10990           0.22360          0.3174              0.14740
# 564          0.11100           0.11590          0.2439              0.13890
# 565          0.09780           0.10340          0.1440              0.09791
# 567          0.11780           0.27700          0.3514              0.15200
# 568          0.05263           0.04362          0.0000              0.00000
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 1    ...        24.990          23.41           158.80      1956.0
# 2    ...        23.570          25.53           152.50      1709.0
# 3    ...        14.910          26.50            98.87       567.7
# 4    ...        22.540          16.67           152.20      1575.0
# 5    ...        15.470          23.75           103.40       741.6
# ..   ...           ...            ...              ...         ...
# 563  ...        24.290          29.41           179.10      1819.0
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# 5             0.17910            0.52490           0.5355
# ..                ...                ...              ...
# 563           0.14070            0.41860           0.6599
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# 5                  0.1741          0.3985                  0.12440
# ..                    ...             ...                      ...
# 563                0.2542          0.2929                  0.09873
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [543 rows x 32 columns]

# %% [markdown]
# I was asked to train and evaluate 3 classification models, KNN, SVC, and Decision Tree on our breast cancer dataset.
#
# After the initial run the accuracy results were
#
# - KNN ~75.7%
#
# - SVC ~63.0%
#
# - Decision Tree ~89.7%
#
# I wasn't necessarily happy with the accuracy.  Since KNN and SVC both work by measuring distances between the data points and since there can be a wide range between these points, the models can get confused.
#
# To fix this I used a method called feature scaling which help the features have similar ranges.  After doing this, the accuracy went up alot:
#
# - KNN = ~97.06%
#
# - SVC = ~97.79%
#
# - Decision Tree = ~93.38%

# %% [markdown]
# # Section 3: Data Exploration
#
# We need to clean the data.<br>
# we want to make sure the data is clean.<br>
# let's see how we can do it using this jupyter notebook<br>

# %% [markdown]
# ## Any Missing Data?

# %%
# to see which columns having missing data (NaN), we can use a function inside pandas.
# Your answers here!

# checking for missing values in every column
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# I used df.isnull().sum() to find missing values in the datset and no columns contained any missing values.
#
# This is mostly because I had already removed/fixed the missing data using df = df.dropna() in the previous cell.  I did this because I kept getting an error when trying to run the models in the previous cell.
#
# Once I removed the missing data the cell ran smoothly.

# %% [markdown]
# ## Fixing Missing Data
# There are two methods we can try:<br>
# 1. remove missing data
# 2. fill missing data with a pre-set value <br>
#
# In this exercise, we will be using the first method. <br>
# If you want to use the second method, you will need to:
# 1. repeat the steps from the beginning
# 2. comment out the steps for method 1 so that you do not accidentally run it.

# %%
# To fix the problem of missing data, there are two possible methods:

# Option 1 : delete missing data row
df = df.dropna()
print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Series([], dtype: int64)

# %%
# Option 2 : replace missing data row
# Your answers here!

# mean_value = df['texture_mean'].mean()
# df["texture_mean"].fillna(value=mean_value, inplace=True)
# df

# %% [markdown]
# ## Rename the column for Target
# Let's rename from diagnosis to target, for better clarity.

# %%
#The column 'diagnosis' has been renamed to 'target'.
df = df.rename(columns={'diagnosis':'target'})

# Can you plot a bar chart to show the number of benign cases (B) and malicious cases (M), using seaborn?
# Your answers here!
import seaborn as sns
import matplotlib.pyplot as plt


sns.countplot(x='target', data=df)
plt.title('Count of Benign and Malignant Cases')
plt.xlabel('Diagnosis')
plt.ylabel('Number of Cases')
plt.show()

print(df.target.value_counts())
# Out:
# target
# B    342
# M    201
# Name: count, dtype: int64

# %% [markdown]
# ## Change the format for Target
# In some of the models, the target need to be in numeric values.<br>
# Therefore let's change the format from string to integer.

# %%
# Change the variable type for 'target' from string to a numeric variable.
# Your answers here!

# changing the target column from string to numeric

df['target'] = df['target'].map({'B': 0, 'M': 1})

# confirming the change
print (df['target'].value_counts())
print(df.dtypes['target'])
# Out:
# target
# 0    342
# 1    201
# Name: count, dtype: int64
# int64

# %% [markdown]
# ## Seeing the Correlation
# In data exploration, it is important to see the correlation between the features.
# Can you find the correlations for all the columns?

# %%
# Your answers here!
corr = df.corr()

plt.figure(figsize=(16,12))
plt.title('Correlations')

sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', square=True, linewidths=0.5)

plt.show()

# %% [markdown]
# I created and used a heat map to clearly show which features strongly correlated with the target (diagnosis).
#
# The closer to 1 (Malignant) = higher correlation to malignance vs. closer to 0 (Benign) = less correlation.
#
# These are the features that are most likely to distinguish between malignant and benigh tumors.
#
# * radius_mean	0.73
# * perimeter_mean	0.74
# * area_mean	0.71
# * concavity_mean	0.70
# * concave points_mean	0.78
# * radius_worst	0.78
# * perimeter_worst	0.88
# * area_worst	0.73
# * concave points_worst	0.80

# %% [markdown]
# ## Finding the top features
# The correlation map is too big. It is hard to extract useful information.<br>
# Is there a way to filter out and find only those that are relevant for our target?

# %%
th = 0.75
filt = np.abs(corr['target']) > th

print('Top correlations with target (threshold> 0.75):')
print(corr['target'][filt])

plt.figure(figsize=(5,3))
sns.heatmap(corr[['target']][filt], annot=True, cmap='coolwarm')
plt.title("Target's correlations greater than " + str(th))

# Can you try other values besides th = 0.75?

for th in [0.6, 0.7, 0.75, 0.8, 0.9]:
    filt = np.abs(corr['target']) > th
    print(f"\nFeatures with correlation greater than {th}:")
    print(corr['target'][filt])
# Out:
# Top correlations with target (threshold> 0.75):
# target                  1.000000
# concave points_mean     0.780981
# radius_worst            0.776534
# perimeter_worst         0.783622
# concave points_worst    0.796219
# Name: target, dtype: float64
#
# Features with correlation greater than 0.6:
# target                  1.000000
# radius_mean             0.730833
# perimeter_mean          0.743755
# area_mean               0.709706
# concavity_mean          0.700099
# concave points_mean     0.780981
# radius_worst            0.776534
# perimeter_worst         0.783622
# area_worst              0.733129
# concavity_worst         0.661141
# concave points_worst    0.796219
# Name: target, dtype: float64
#
# Features with correlation greater than 0.7:
# target                  1.000000
# radius_mean             0.730833
# perimeter_mean          0.743755
# area_mean               0.709706
# concavity_mean          0.700099
# concave points_mean     0.780981
# radius_worst            0.776534
# perimeter_worst         0.783622
# area_worst              0.733129
# concave points_worst    0.796219
# Name: target, dtype: float64
#
# Features with correlation greater than 0.75:
# target                  1.000000
# concave points_mean     0.780981
# radius_worst            0.776534
# perimeter_worst         0.783622
# concave points_worst    0.796219
# Name: target, dtype: float64
#
# Features with correlation greater than 0.8:
# target    1.0
# Name: target, dtype: float64
#
# Features with correlation greater than 0.9:
# target    1.0
# Name: target, dtype: float64

# %%
# Let's use X to create the data for features
# Let's use y to create the data for target
# Your answers here!

df_clean = df.dropna()

X = df_clean.drop(columns=['target'])
y= df_clean['target']

columns = X.columns.tolist()

# Split the data for both training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
print('X_train.shape:', X_train.shape)
print('X_test.shape:', X_test.shape)
# Out:
# X_train.shape: (434, 31)
# X_test.shape: (109, 31)

# %%
# Let's standardize the data so that the range of the features are similar
# Your answers here!
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_df = pd.DataFrame(X_train, columns = columns)
X_train_df["target"] = y_train

# %% [markdown]
# # Section 4: Modeling
#
# We will be using 3 models:<br>
# 1. KNN
# 2. SVM
# 3. Decision Tree <br>
#
# We will compare how each one works.<br>
# But before that, we will do some preparation first.

# %%
# Your answer here! (KNN)

# creating and training the model
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

# making predictions
knn_predictions = knn.predict(X_test_scaled)

# analyzing the model
print('RNN Results:')
print(confusion_matrix(y_test, knn_predictions))
print(classification_report(y_test, knn_predictions, target_names=['Benign', 'Malignant']))
print('Accuracy:', accuracy_score(y_test, knn_predictions))
# Out:
# RNN Results:
# [[64  0]
#  [ 4 41]]
#               precision    recall  f1-score   support
#
#       Benign       0.94      1.00      0.97        64
#    Malignant       1.00      0.91      0.95        45
#
#     accuracy                           0.96       109
#    macro avg       0.97      0.96      0.96       109
# weighted avg       0.97      0.96      0.96       109
#
# Accuracy: 0.963302752293578

# %%
# Your answer here! (SVM)

# creating and training the SVM model
svm = SVC(kernel='linear')
svm.fit(X_train_scaled, y_train)


# making predictions
svm_predictions = svm.predict(X_test_scaled)

# analyzing the model
print('Original SVM Results:')
print(confusion_matrix(y_test, svm_predictions))
print(classification_report(y_test, svm_predictions, target_names=['Benign', 'Malignant']))
print('Accuracy:', accuracy_score(y_test, svm_predictions))
# Out:
# Original SVM Results:
# [[64  0]
#  [ 1 44]]
#               precision    recall  f1-score   support
#
#       Benign       0.98      1.00      0.99        64
#    Malignant       1.00      0.98      0.99        45
#
#     accuracy                           0.99       109
#    macro avg       0.99      0.99      0.99       109
# weighted avg       0.99      0.99      0.99       109
#
# Accuracy: 0.9908256880733946

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

# Try different settings to find the best one
params = {
    'kernel': ['linear', 'rbf'],
    'C': [1, 10],
    'gamma': ['scale', 0.1]
}

# Grid search does the work for us
grid = GridSearchCV(SVC(), params, cv=3, verbose=2)

grid.fit(X_train_scaled, y_train)

# Best model
print("Fine-Tuned SVM Best Settings:", grid.best_params_)

# Predict and evaluate
best_model = grid.best_estimator_
predictions = best_model.predict(X_test_scaled)

print("Fine-Tuned SVM Results:")
print("Accuracy:", accuracy_score(y_test, predictions))
print(classification_report(y_test, predictions, target_names=['Benign', 'Malignant']))
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time=   0.0s
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time=   0.0s
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# Fine-Tuned SVM Best Settings: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Fine-Tuned SVM Results:
# Accuracy: 0.981651376146789
#               precision    recall  f1-score   support
#
#       Benign       0.97      1.00      0.98        64
#    Malignant       1.00      0.96      0.98        45
#
#     accuracy                           0.98       109
#    macro avg       0.98      0.98      0.98       109
# weighted avg       0.98      0.98      0.98       109

# %%
# Your answer here! (Decision Tree)

#creating and training the model
dtree= DecisionTreeClassifier(random_state=42)
dtree.fit(X_train, y_train)

#making predictions
dtree_predictions = dtree.predict(X_test)

#analyzing the model
print('Decision Tree Results:')
print(confusion_matrix(y_test, dtree_predictions))
print(classification_report(y_test, dtree_predictions, target_names=['Benign', 'Malignant']))
print('Accuracy:', accuracy_score(y_test, dtree_predictions))
# Out:
# Decision Tree Results:
# [[61  3]
#  [ 2 43]]
#               precision    recall  f1-score   support
#
#       Benign       0.97      0.95      0.96        64
#    Malignant       0.93      0.96      0.95        45
#
#     accuracy                           0.95       109
#    macro avg       0.95      0.95      0.95       109
# weighted avg       0.95      0.95      0.95       109
#
# Accuracy: 0.9541284403669725

# %% [markdown]
# # Section 5: Evaluation
# We want to check the performance of our model. <br>
# We want to know the accuracy of the results.

# %%
# Your answer here! (KNN)
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

y_pred_test1 = knn.predict(X_test_scaled)

acc_test = accuracy_score(y_test, y_pred_test1)
acc_train = accuracy_score(y_train, knn.predict(X_train_scaled))

cm = confusion_matrix(y_test, knn_predictions)


print("Test Score: {}, Train Score: {}".format(round(acc_test,4), round(acc_train,4)))
print("CM: \n",cm)
plt.figure(figsize=(3,3))
sns.heatmap(cm, annot=True)
print(classification_report(y_test, y_pred_test1))
# Out:
# Test Score: 0.9633, Train Score: 0.9724
# CM:
#  [[64  0]
#  [ 4 41]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        64
#            1       1.00      0.91      0.95        45
#
#     accuracy                           0.96       109
#    macro avg       0.97      0.96      0.96       109
# weighted avg       0.97      0.96      0.96       109

# %% [markdown]
# **Test Accuracy** = 97.25%
#
# **Train Accuracy** = 97.93%
#
#
# KNN definitely demonstrates a very strong predictive performance. There were only 4 misclassifications overall. *italicized text*

# %%
# Your answer here! (SVM)

y_pred_test2 = svm.predict(X_test_scaled)

acc_test2 = accuracy_score(y_test, y_pred_test2)
acc_train2 = accuracy_score(y_train, dtree.predict(X_train))

cm2 = confusion_matrix(y_test, y_pred_test2)



print("Test Score: {}, Train Score: {}".format(round(acc_test2,4), round(acc_train2,4)))
print("CM: \n",cm2)
plt.figure(figsize=(3,3))
sns.heatmap(cm2, annot=True)
print(classification_report(y_test, y_pred_test2))
# Out:
# Test Score: 0.9908, Train Score: 1.0
# CM:
#  [[64  0]
#  [ 1 44]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        64
#            1       1.00      0.98      0.99        45
#
#     accuracy                           0.99       109
#    macro avg       0.99      0.99      0.99       109
# weighted avg       0.99      0.99      0.99       109

# %% [markdown]
# **Test Accuracy** = 97.25%
#
# **Train Accuracy** = 100%
#
#
# SVM definitely demonstrates a very strong predictive performance. There were only 2 misclassifications overall.

# %%
# Your answer here! (Decision Tree)

y_pred_test3 = dtree.predict(X_test)

acc_test3 = accuracy_score(y_test, y_pred_test3)
acc_train3 = accuracy_score(y_train, dtree.predict(X_train))

cm3 = confusion_matrix(y_test, y_pred_test2)


print("Test Score: {}, Train Score: {}".format(round(acc_test3,4), round(acc_train3,4)))
print("CM: \n",cm3)
plt.figure(figsize=(3,3))
sns.heatmap(cm3, annot=True)
print(classification_report(y_test, y_pred_test3))
# Out:
# Test Score: 0.9541, Train Score: 1.0
# CM:
#  [[64  0]
#  [ 1 44]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96        64
#            1       0.93      0.96      0.95        45
#
#     accuracy                           0.95       109
#    macro avg       0.95      0.95      0.95       109
# weighted avg       0.95      0.95      0.95       109

# %% [markdown]
# # What is your best model?
# In order to get best model, you will need to modify the parameters. <br>
# Look back at the models in section 4, can you fine tune it better? <br><br>
# What is your best model? How does it fare?

# %%
# My best model: SVM

# It achieved the highest accuracy at ~98.5% on the test set.

# 100% on training data.

# I did go back and try to fine-tune by using the RBF kernel with C=1 and
# gamma='scale' which gave a 97.2% accuracy.

# The original SVM model did slightly better at ~98.5%.

# Since we are working with data that is literally life or death,
# I believe it's the safest and most responsible decision to use a model
# that performs best on detecting malignant cases.

# There is a clear winner when it comes to the highest
# accuracy and high recall for malignant tumors.

# The original SVM model.

# %% [markdown]
# # Section 6: Deployment
# What makes a good deployment? <br>
# It has to be useful and easy to use. <br>
# It needs to be updated frequently and easily.<br>
# Deployment can be on-premise or online.<br>
#
# In the cell below, write down your suggestions on how you can deploy this AI model.

# %%
# I would make a simple and easy to use web/mobile app for medical professionals.

# So data can be inputted and results given back quickly.

# It really wouldn't need a lot of bells and whistles design wise. It just needs to work!

# Deploying on the cloud is also best so it can be accessed from anywhere since most medical
# professionals that would handle this data work at many locations.

# The model would need to continuously be updated with new data so it can stay reliable,
# accurate, and save lives.

# A big emphasis on security would been needed since this is very sensitive data and
# following HIPAA laws must be a priority.

# Model's performance would need to be monitored and any issues to be fixed quickly.

# %% [markdown]
# # Other Reading Materials
# You can get more information through these materials: <br>
# 1. https://www.breastcancer.org/symptoms/understand_bc/statistics
# 2. https://scikit-learn.org/stable/
# 3. https://pandas.pydata.org/docs/reference/api/pandas.isnull.html
# 4. https://seaborn.pydata.org/generated/seaborn.clustermap.html
# 5. https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
# 6. https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
# 7. https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# 8. https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# 9. https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
